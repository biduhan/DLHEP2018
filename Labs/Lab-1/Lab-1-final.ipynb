# %% [markdown]
# ## Lab 1- Python
#
# Let start with generating some fake random data. You can get a random number between 0 and 1 using the python random module as follow:

# %%
import random
x=random.random()
print "The Value of x is", x
# Out:
# The Value of x is 0.894362142602

# %% [markdown]
# ### Exercise 1.1
# Using random, write a function GenerateData(N, mymin, mymax), that returns a python list containing N random numbers between specified minimum and maximum value. Note that you may want to quickly work out on paper how to turn numbers between 0 and 1 to between other values.

# %%
# Skeleton
import random

def GenerateData(N,min,max):
    out = []
    
    ### BEGIN SOLUTION
    for i in range(N):
        x = random.random()    
        rand = (max-min)*x + min
        out.append(rand)
    ### END SOLUTION
    
    return out

Data=GenerateData(1000,-10,10)
print "Data Type:", type(Data)
print "Data Length:", len(Data)
if len(Data)>0: 
    print "Type of Data Contents:", type(Data[0])
    print "Data Minimum:", min(Data)
    print "Data Maximum:", max(Data)
# Out:
# Data Type: <type 'list'>
# Data Length: 1000
# Type of Data Contents: <type 'float'>
# Data Minimum: -9.99223801298
# Data Maximum: 9.98461672894

# %% [markdown]
# ### Exercise 1.2
#
# Write a function that computes the mean of values in a list.

# %%
# Skeleton
def mean(Data):
    m=0
    
    ### BEGIN SOLUTION
    total = 0
    length = len(Data)
    for i in range(length):
        total = total + Data[i]
        m = total/length        
    ### END SOLUTION
    
    return m

print "Mean of Data:", mean(Data)
# Out:
# Mean of Data: -0.103984762819

# %% [markdown]
# ### Exercise 1.3
#
# Write a function the applies a booling function (that returns true/false) to every element in data, and return a list of indices of elements where the result was true. Use this function to find the indices of positive entries.

# %%
def booling(num):
    if num <= 0:
        return False
    if num > 0:
        return True

# %%
def where(mylist,myfunc):
    out= []
    
    ### BEGIN SOLUTION
    out = []
    length = len(mylist)
    t_or_f = []
    for i in range(length):
        t_or_f.append(myfunc(mylist[i]))
        if t_or_f[i] == True:
            out.append(i)       
    ### END SOLUTION
    
    return out

# %%
where(Data,booling)
# Out:
# [0,
#  1,
#  3,
#  6,
#  10,
#  11,
#  12,
#  15,
#  19,
#  22,
#  25,
#  26,
#  27,
#  28,
#  30,
#  37,
#  39,
#  41,
#  43,
#  44,
#  45,
#  46,
#  49,
#  50,
#  51,
#  52,
#  53,
#  58,
#  59,
#  62,
#  63,
#  65,
#  68,
#  70,
#  72,
#  73,
#  75,
#  76,
#  80,
#  84,
#  85,
#  86,
#  87,
#  91,
#  92,
#  93,
#  96,
#  97,
#  98,
#  100,
#  101,
#  102,
#  104,
#  105,
#  107,
#  113,
#  117,
#  118,
#  119,
#  120,
#  124,
#  125,
#  126,
#  127,
#  128,
#  131,
#  133,
#  134,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  147,
#  150,
#  151,
#  152,
#  154,
#  155,
#  156,
#  160,
#  161,
#  162,
#  165,
#  167,
#  171,
#  172,
#  175,
#  176,
#  178,
#  179,
#  180,
#  182,
#  183,
#  184,
#  185,
#  191,
#  195,
#  199,
#  205,
#  206,
#  208,
#  210,
#  211,
#  213,
#  215,
#  216,
#  219,
#  220,
#  221,
#  223,
#  226,
#  227,
#  228,
#  230,
#  231,
#  232,
#  233,
#  234,
#  239,
#  240,
#  241,
#  242,
#  243,
#  245,
#  246,
#  248,
#  249,
#  250,
#  251,
#  253,
#  255,
#  259,
#  266,
#  267,
#  268,
#  270,
#  274,
#  277,
#  278,
#  279,
#  281,
#  283,
#  284,
#  285,
#  286,
#  288,
#  291,
#  293,
#  295,
#  300,
#  301,
#  304,
#  308,
#  313,
#  316,
#  317,
#  318,
#  319,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  330,
#  331,
#  333,
#  337,
#  340,
#  342,
#  343,
#  345,
#  347,
#  349,
#  351,
#  352,
#  356,
#  357,
#  360,
#  361,
#  362,
#  363,
#  364,
#  366,
#  367,
#  368,
#  369,
#  370,
#  375,
#  376,
#  377,
#  378,
#  385,
#  386,
#  388,
#  395,
#  399,
#  403,
#  408,
#  411,
#  412,
#  414,
#  416,
#  417,
#  418,
#  419,
#  420,
#  421,
#  426,
#  427,
#  429,
#  432,
#  433,
#  435,
#  436,
#  438,
#  440,
#  443,
#  446,
#  447,
#  448,
#  449,
#  450,
#  451,
#  452,
#  454,
#  456,
#  458,
#  461,
#  462,
#  465,
#  466,
#  467,
#  468,
#  470,
#  471,
#  474,
#  476,
#  477,
#  478,
#  479,
#  483,
#  484,
#  485,
#  486,
#  487,
#  489,
#  491,
#  493,
#  496,
#  497,
#  500,
#  502,
#  506,
#  507,
#  509,
#  511,
#  513,
#  515,
#  516,
#  517,
#  518,
#  521,
#  522,
#  523,
#  524,
#  527,
#  529,
#  530,
#  537,
#  538,
#  540,
#  542,
#  543,
#  547,
#  549,
#  551,
#  553,
#  556,
#  557,
#  558,
#  559,
#  563,
#  564,
#  565,
#  572,
#  574,
#  576,
#  577,
#  589,
#  590,
#  592,
#  594,
#  596,
#  600,
#  603,
#  604,
#  605,
#  610,
#  613,
#  619,
#  621,
#  623,
#  626,
#  627,
#  628,
#  629,
#  631,
#  633,
#  634,
#  636,
#  637,
#  639,
#  640,
#  650,
#  651,
#  653,
#  654,
#  655,
#  656,
#  659,
#  661,
#  665,
#  666,
#  667,
#  668,
#  669,
#  670,
#  671,
#  672,
#  673,
#  674,
#  675,
#  681,
#  685,
#  686,
#  687,
#  689,
#  690,
#  692,
#  693,
#  694,
#  696,
#  705,
#  706,
#  707,
#  708,
#  709,
#  713,
#  715,
#  716,
#  718,
#  719,
#  722,
#  723,
#  725,
#  726,
#  727,
#  729,
#  730,
#  732,
#  733,
#  735,
#  738,
#  740,
#  741,
#  744,
#  745,
#  747,
#  748,
#  750,
#  752,
#  753,
#  754,
#  755,
#  758,
#  759,
#  762,
#  763,
#  765,
#  766,
#  768,
#  771,
#  772,
#  773,
#  774,
#  776,
#  777,
#  783,
#  788,
#  789,
#  790,
#  791,
#  794,
#  797,
#  799,
#  802,
#  803,
#  804,
#  806,
#  807,
#  809,
#  812,
#  813,
#  814,
#  816,
#  818,
#  819,
#  820,
#  822,
#  823,
#  824,
#  825,
#  826,
#  829,
#  832,
#  833,
#  836,
#  839,
#  846,
#  848,
#  850,
#  853,
#  854,
#  855,
#  856,
#  858,
#  861,
#  862,
#  866,
#  867,
#  868,
#  871,
#  873,
#  876,
#  878,
#  885,
#  886,
#  890,
#  891,
#  893,
#  894,
#  895,
#  898,
#  900,
#  902,
#  903,
#  904,
#  910,
#  916,
#  922,
#  924,
#  926,
#  928,
#  930,
#  931,
#  932,
#  934,
#  936,
#  938,
#  941,
#  944,
#  945,
#  946,
#  950,
#  953,
#  954,
#  955,
#  957,
#  958,
#  961,
#  962,
#  964,
#  967,
#  973,
#  974,
#  976,
#  977,
#  978,
#  980,
#  981,
#  984,
#  985,
#  986,
#  989,
#  990,
#  994,
#  995,
#  998,
#  999]

# %% [markdown]
# ### Exercise 1.4
#
# The inrange(mymin,mymax) function below returns a function that tests if it's input is between the specified values. Use this function, in conjunction to your solution to 1.3, to demonstrate that your data is "flat". Hint: pick several sub-ranges and show that the number of data point divided by the size of the range is roughly constant.

# %%
def inrange(mymin,mymax):
    def testrange(x):
        return x<mymax and x>=mymin
    return testrange

R = 5.0
R1 = inrange(-10,- 5)
R2 = inrange(- 5,  0)
R3 = inrange(  0,  5)
R4 = inrange(  5, 10)

print "Number of Entries passing R1/the size of R1:", len(where(Data,R1))/R
print "Number of Entries passing R2/the size of R2:", len(where(Data,R2))/R
print "Number of Entries passing R3/the size of R3:", len(where(Data,R3))/R
print "Number of Entries passing R4/the size of R4:", len(where(Data,R4))/R

# Examples:
#F1=inrange(0,10)
#F2=inrange(10,20)

#print F1(0), F1(1), F1(10), F1(15), F1(20)
#print F2(0), F2(1), F2(10), F2(15), F2(20)

#print "Number of Entries passing F1:", len(where(Data,F1))
#print "Number of Entries passing F2:", len(where(Data,F2))
# Out:
# Number of Entries passing R1/the size of R1: 49.0
# Number of Entries passing R2/the size of R2: 52.4
# Number of Entries passing R3/the size of R3: 52.4
# Number of Entries passing R4/the size of R4: 46.2

# %% [markdown]
# ### Exercise 1.5
#
# Repeat Exercise 1.5 using the built in python functions sum and map instead of your solution to 1.3.

# %%
### BEGIN SOLUTION

sum(map(booling,Data))    
    
### END SOLUTION
# Out:
# 493

# %% [markdown]
# ### Exercise 1.6
#
# Write a new function called GenerateDataFromFunction(N,mymin,mymax,myfunc), that instead of generating a flat distribution, generates a distribution with functional form coded in myfunc. Note that myfunc will always be > 0.
#
# Use your function to generate 1000 numbers that are Gaussian distributed, using the Gaussian function below. Confirm the mean of the data is close to mean you specify when building the Gaussian.
#
# Hint: A simple, but slow, solution is to a draw random number test_x within the specified range and another number p between the min and max of the function (which you will have to determine). If p<=function(test_x), then place test_x on the output. If not, repeat the process, drawing two new numbers. Repeat until you have the specified number of generated numbers, N. For this problem, it's OK to determine the min and max by numerically sampling the function.

# %%
def GenerateDataFromFunction(N,mymin,mymax,myfunc):
    out = []
    
    ### BEGIN SOLUTION

    r = mymax - mymin
    mean = (mymax + mymin)/2
    sigma = r/2
    i = 0
    while i < N:
        x = random.uniform(mymin-sigma,mymax+sigma)
        max1 = myfunc(mean)
        y = random.uniform(0,max1)
        if y <= myfunc(x):
            out.append(x)
            i = i + 1
    #my own attempt at a gaussian
    #while len(out) < N:
        #p1 = (mymax - mymin)*random.random() + mymin
        #p2 = (mymax - mymin)*random.random() + mymin
        #x = (mymax - mymin)*random.random() + mymin
        #if p1 < p2:
            #if p2 >= x and x >= p1:
                #out.append(x)
        #else:
            #if p2 <= x and x <= p1:
                #out.append(x)   
    
    ### END SOLUTION
    
    return out

# %%
import math

def gaussian(mean, sigma):
    def f(x):
        return math.exp(-((x-mean)**2)/(2*sigma**2))/math.sqrt(math.pi*sigma)
    return f

# Example Instantiation
g1=gaussian(0,1)
g2=gaussian(10,3)



### BEGIN SOLUTION

G1data = []
G1j = []
G2data = []
G2j = []
N = 1000
j = 0
for i in range(N+1):
    G1j.append(4.0*j/N-2.0)
    G2j.append(12.0*j/N+4.0)
    G1data.append(g1(4.0*j/N-2.0))
    G2data.append(g2(12.0*j/N+4.0))
    j = j + 1
print "Mean of the first gaussian: ", sum(G1j)/(N+1)
print "Mean of the second gaussian:", sum(G2j)/(N+1)

H1 = GenerateDataFromFunction(N,-1,1,g1)
H2 = GenerateDataFromFunction(N,7,13,g2)

#my own attempt at a gaussian
#GData = GenerateDataFromFunction(1000,2.5,27.5,booling)
#sum = 0
#for i in range(len(GData)):
    #sum = sum + GData[i]
    #average = sum/len(GData)
#print "Average value:", (average)
#R = 5.0
#R1 = inrange(2.5,7.5)
#R2 = inrange(7.5,12.5)
#R3 = inrange(12.5,17.5)
#R4 = inrange(17.5,22.5)
#R5 = inrange(22.5,27.5)

#print "Number of Entries passing R1/(the size of R1):", len(where(GData,R1))/R
#print "Number of Entries passing R2/(the size of R2):", len(where(GData,R2))/R
#print "Number of Entries passing R3/(the size of R3):", len(where(GData,R3))/R
#print "Number of Entries passing R4/(the size of R4):", len(where(GData,R4))/R
#print "Number of Entries passing R5/(the size of R5):", len(where(GData,R5))/R

### END SOLUTION
# Out:
# Mean of the first gaussian:  -4.74700753786e-17
# Mean of the second gaussian: 10.0
